# %%
# !pip install yfinance
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 kB 7.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 109.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.5/73.5 kB 9.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 14.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 99.3 MB/s eta 0:00:00:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.3/19.3 MB 86.9 MB/s eta 0:00:00:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 102.3 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 33.4 MB/s eta 0:00:00
# ...
#   Created wheel for peewee: filename=peewee-3.17.6-py3-none-any.whl size=138891 sha256=5ddfca12e26db6677a91b3a943373d6aba4900229a2b7fcf8595cd7d13513515
# ...

# %%
import yfinance as yf
import pandas as pd

# %%
# Define the ticker symbol for Tesla
ticker_symbol = 'TSLA'

# %%
# Create a ticker object for Tesla
tesla = yf.Ticker(ticker_symbol)

# %%
# Get Tesla's quarterly financials (income statement)
tesla_financials = tesla.quarterly_financials

# %%
# Display the financials
print(tesla_financials)
# Out:
#                                                        2024-03-31  \
# Tax Effect Of Unusual Items                                   0.0
# Tax Rate For Calcs                                           0.26
# Normalized EBITDA                                    2875000000.0
# Total Unusual Items                                           NaN
# Total Unusual Items Excluding Goodwill                        NaN
# Net Income From Continuing Operation Net Minori...   1129000000.0
# Reconciled Depreciation                              1246000000.0
# Reconciled Cost Of Revenue                          17605000000.0
# EBITDA                                               2875000000.0
# EBIT                                                 1629000000.0
# Net Interest Income                                   274000000.0
# Interest Expense                                       76000000.0
# Interest Income                                       350000000.0
# ...

# %%
# Extract the revenue data
revenue_data = tesla_financials.loc['Total Revenue']

# %%
# Display the last five rows of the revenue data
print(revenue_data.tail())
# Out:
# 2023-12-31    25167000000.0
# 2023-09-30    23350000000.0
# 2023-06-30    24927000000.0
# 2023-03-31    23329000000.0
# 2022-12-31              NaN
# Name: Total Revenue, dtype: object

# %%
# Define the ticker symbol for Gamestop
ticker_symbol = 'GME'

# %%
# Create a ticker object for Gamestop
gamestop = yf.Ticker(ticker_symbol)

# %%
# Get Gamestop's quarterly financials (income statement)
gamestop_financials = gamestop.quarterly_financials

# %%
# Display the financials
print(gamestop_financials)
# Out:
#                                                          2024-01-31  \
# Tax Effect Of Unusual Items                          -534084.507042
# Tax Rate For Calcs                                         0.111268
# Normalized EBITDA                                        83400000.0
# Total Unusual Items                                      -4800000.0
# Total Unusual Items Excluding Goodwill                   -4800000.0
# Net Income From Continuing Operation Net Minori...       63100000.0
# Reconciled Depreciation                                  18600000.0
# Reconciled Cost Of Revenue                             1374400000.0
# EBITDA                                                   78600000.0
# EBIT                                                     60000000.0
# Net Interest Income                                      15300000.0
# Interest Income                                                 NaN
# Normalized Income                                   67365915.492958
# ...

# %%
# Extract the revenue data
revenue_data = gamestop_financials.loc['Total Revenue']

# %%
# Display the last five rows of the revenue data
print(revenue_data.tail())
# Out:
# 2023-10-31    1078300000.0
# 2023-07-31    1163800000.0
# 2023-04-30    1237100000.0
# 2023-01-31    2226400000.0
# 2022-10-31             NaN
# Name: Total Revenue, dtype: object

# %%
make_graph(tesla_data, tesla_revenue, "Tesla")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 make_graph(tesla_data, tesla_revenue, "Tesla")
#
# NameError: name 'make_graph' is not defined

# %%
make_graph(gme_data, gme_revenue, "GameStop")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 make_graph(gme_data, gme_revenue, "GameStop")
#
# NameError: name 'make_graph' is not defined

# %%
# !pip install matplotlib
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.6/162.6 kB 19.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.3/8.3 MB 103.0 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.0/306.0 kB 38.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 120.9 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 61.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 117.4 MB/s eta 0:00:0000:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.2/103.2 kB 13.4 MB/s eta 0:00:00
# ...

# %%
import yfinance as yf
import matplotlib.pyplot as plt

# %%
# Create a Ticker object for Tesla
TSLA = yf.Ticker("TSLA")

# Download historical stock data for Tesla with the period set to 'max'
tesla_history = tesla.history(period="max")

# %%
# Plot the closing prices
plt.figure(figsize=(14, 7))
plt.plot(tesla_history.index, tesla_history['Close'], label='AMD Closing Price')

# Add title and labels
plt.title('Tesla Stock Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Add a legend
plt.legend()

# Display the plot
plt.show()

# %%
# Create a Ticker object for GameStop
GME = yf.Ticker("GME")

# Download historical stock data for GameStop with the period set to 'max'
gamestop_history = gamestop.history(period="max")

# %%
# Plot the closing prices
plt.figure(figsize=(14, 7))
plt.plot(tesla_history.index, gamestop_history['Close'], label='gamestop Closing Price')

# Add title and labels
plt.title('gamestop Stock Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Add a legend
plt.legend()

# Display the plot
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 3
#       1 # Plot the closing prices
#       2 plt.figure(figsize=(14, 7))
# ----> 3 plt.plot(tesla_history.index, gamestop_history['Close'], label='gamestop Closing Price')
#       5 # Add title and labels
#       6 plt.title('gamestop Stock Closing Prices Over Time')
#
# File /opt/conda/lib/python3.11/site-packages/matplotlib/pyplot.py:3794, in plot(scalex, scaley, data, *args, **kwargs)
#    3786 @_copy_docstring_and_deprecators(Axes.plot)
#    3787 def plot(
#    3788     *args: float | ArrayLike | str,
#    (...)
#    3792     **kwargs,
#    3793 ) -> list[Line2D]:
# -> 3794     return gca().plot(
#    3795         *args,
#    3796         scalex=scalex,
#    3797         scaley=scaley,
#    3798         **({"data": data} if data is not None else {}),
#    3799         **kwargs,
#    3800     )
#
# ...

# %%
# Plot the closing prices
plt.figure(figsize=(14, 7))
plt.plot(gamestop_history.index, gamestop_history['Close'], label='GameStop Closing Price')

# Add title and labels
plt.title('GaneStop Stock Closing Prices Over Time')
plt.xlabel('Date')
plt.ylabel('Closing Price (USD)')

# Add a legend
plt.legend()

# Display the plot
plt.show()
